# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Load cleaned dataset
df = pd.read_csv("C:/Users/chadh/Desktop/Academic projects/BI-AI-Job-Market/data/cleaned/ai_job_market_cleaned.csv")


# Quick check
df.head()
# Out:
#                Job Title       Industry  Job Status AI Impact Level  \
# 0     Investment Analyst             It  Increasing        Moderate
# 1  Journalist, Newspaper  Manufacturing  Increasing        Moderate
# 2      Financial Planner        Finance  Increasing             Low
# 3        Legal Secretary     Healthcare  Increasing            High
# 4  Aeronautical Engineer             It  Increasing             Low
#
#    Median Salary (USD) Required Education  Experience Required (Years)  \
# 0             42109.76    Master’S Degree                            5
# 1            132298.57    Master’S Degree                           15
# 2            143279.19  Bachelor’S Degree                            4
# 3             97576.13   Associate Degree                           15
# 4             60956.63    Master’S Degree                           13
#
#    Job Openings (2024)  Projected Openings (2030)  Remote Work Ratio (%)  \
# 0                 1515                       6342                  55.96
# 1                 1243                       6205                  16.81
# 2                 3338                       1154                  91.82
# 3                 7173                       4060                   1.89
# 4                 5944                       7396                  53.76
#
#    Automation Risk (%)   Location  Gender Diversity (%)  Net Job Change  \
# 0                28.28         Uk                 44.63            4827
# 1                89.71        Usa                 66.39            4962
# 2                72.97     Canada                 41.13           -2184
# 3                99.94  Australia                 65.76           -3113
# 4                37.65    Germany                 72.57            1452
#
#    Percent Job Change  AI Impact Score  Career Stability Index  \
# 0              318.61                2                  228.51
# 1              399.20                2                   41.08
# 2              -65.43                1                  -17.69
# 3              -43.40                3                   -0.03
# 4               24.43                1                   15.23
#
#    Median Salary Norm  High-Opportunity Career Score
# 0                0.10                           1.52
# 1                0.85                           1.88
# 2                0.94                           0.10
# 3                0.56                          -0.00
# 4                0.26                           0.36

# %%
features = [
    "Automation Risk (%)",
    "Percent Job Change",
    "Median Salary Norm",
    "Remote Work Ratio (%)",
    "AI Impact Score",
    "Career Stability Index"
]

X = df[features].copy()
X.describe()
# Out:
#        Automation Risk (%)  Percent Job Change  Median Salary Norm  \
# count         30000.000000        30000.000000        30000.000000
# mean             50.154229          141.035263            0.500998
# std              28.754889          556.652291            0.286817
# min               0.000000          -98.940000            0.000000
# 25%              25.400000          -49.365000            0.250000
# 50%              50.020000            0.305000            0.500000
# 75%              75.030000           97.582500            0.750000
# max              99.990000         8945.100000            1.000000
#
#        Remote Work Ratio (%)  AI Impact Score  Career Stability Index
# count           30000.000000     30000.000000            30000.000000
# mean               49.836431         2.001733               69.870087
# std                28.966688         0.815651              329.143120
# min                 0.000000         1.000000              -97.090000
# 25%                24.570000         1.000000              -18.390000
# 50%                49.570000         2.000000                0.050000
# 75%                75.100000         3.000000               38.432500
# max               100.000000         3.000000             8199.080000

# %%
# Fill missing values with column mean
X = X.fillna(X.mean())

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df["JobCluster"] = kmeans.fit_predict(X_scaled)

df["JobCluster"].value_counts()
# Out:
# JobCluster
# 1    14874
# 0    14533
# 2      593
# Name: count, dtype: int64

# %%
cluster_profile = (
    df.groupby("JobCluster")[features]
    .mean()
    .round(2)
)

cluster_profile
# Out:
#             Automation Risk (%)  Percent Job Change  Median Salary Norm  \
# JobCluster
# 0                         50.66               76.25                0.50
# 1                         50.03               79.74                0.50
# 2                         40.96             3266.16                0.51
#
#             Remote Work Ratio (%)  AI Impact Score  Career Stability Index
# JobCluster
# 0                           75.21             1.98                   33.72
# 1                           25.09             2.02                   35.98
# 2                           48.77             1.98                 1805.74

# %%
cluster_labels = {
    0: "Future-Proof & High Growth",
    1: "High Salary but High Risk",
    2: "Stable but Low Growth"
}

df["Career Cluster Label"] = df["JobCluster"].map(cluster_labels)

df[["Job Title", "Industry", "Career Cluster Label"]].head()
# Out:
#                Job Title       Industry        Career Cluster Label
# 0     Investment Analyst             It  Future-Proof & High Growth
# 1  Journalist, Newspaper  Manufacturing   High Salary but High Risk
# 2      Financial Planner        Finance  Future-Proof & High Growth
# 3        Legal Secretary     Healthcare   High Salary but High Risk
# 4  Aeronautical Engineer             It  Future-Proof & High Growth

# %%
output_path = "../advanced_analysis/ai_job_market_with_clusters.csv"
df.to_csv(output_path, index=False)

print("File saved:", output_path)
# Out:
# File saved: ../advanced_analysis/ai_job_market_with_clusters.csv

# %%
df["Career Cluster Label"].value_counts()
# Out:
# Career Cluster Label
# High Salary but High Risk     14874
# Future-Proof & High Growth    14533
# Stable but Low Growth           593
# Name: count, dtype: int64
